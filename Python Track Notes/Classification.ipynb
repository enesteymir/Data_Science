# %% [markdown]
# Supervised Learning - KNeighborsClassifier - Accuracy

# %%
# doing with labeled data
# in classification , we target variable consists of categories
# Exploratory data analysis (EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## datamız binary yani 1 0 olduğundan seabornun countplot fonksiyonunu kullandık

plt.figure()
sns.countplot(x='education', hue='party', data=df, palette='RdBu')   ## x eksenindeki education, sütunlar party,datamız df ve rengımız rdbu
plt.xticks([0,1], ['No', 'Yes'])  ## evet ve hayır kategorimiz var
plt.show()

# %%
(3,4) means 3 observations and 4 features

# %%
# Import KNeighborsClassifier from sklearn.neighbors
from sklearn.neighbors import KNeighborsClassifier

# Create arrays for the features and the response variable
y = df['party'].values  ## target variable
X = df.drop('party', axis=1).values ## delete the target variable and get data

# Create a k-NN classifier with 6 neighbors
knn = KNeighborsClassifier(n_neighbors=6)

# Fit the classifier to the data
knn.fit(X,y) 

# Predict the labels for the training data X: y_pred
y_pred = knn.predict(X)

# Predict and print the label for the new data point X_new (unlabeled data)
new_prediction = knn.predict(X_new)
print("Prediction: {}".format(new_prediction))

# %%
Accuracy = fraction of correct prediction
