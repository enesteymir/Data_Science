# %%
##MAKING EASY PLOTS WITH MATPLOTLIB

import matplotlib.pyplot as plt
plt.plot(x,y)                     ##x is horizantal list - x axis, y is vertical list-y axis
plt.show()

# %%
When you have a time scale along the horizontal axis, the line plot is your friend.
But in many other cases, when you're trying to assess if there's a correlation between two variables,
for example, the scatter plot is the better choice.
Below is an example of how to build a scatter plot

import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

plt.xscale('log') makes the x axis logarithmic

# %%
Use plt.hist() to create a histogram.
By default, python put 10 bins if you dont set number

The number of bins is pretty important. Too few bins will oversimplify reality and won't show you the details.
Too many bins will overcomplicate reality and won't show the bigger picture.

plt.show() displays a plot; plt.clf() cleans it up again so you can start afresh.

# %%
## Adding title and labels to our plot;

xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)

or wirte directly;

plt.xlabel('GDP per Capita [in USD]')

# %%
For customizing the values of x and y

# Definition of tick_val and tick_lab
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val,tick_lab)

# %%
## SIZE OF THE PLOT

import numpy as np

# Store pop as a numpy array: np_pop (we have a population list)
np_pop = np.array(pop)

# Double np_pop ( we made it doubled because it is an array)
np_pop = np_pop * 2

# Update: set s argument to np_pop ( s is the size of the dots in the scatter plot)
plt.scatter(gdp_cap, life_exp, s = np_pop)

# %%
## COLORS OF THE PLOT

## "col" is the list of colors and it was made by dictionary ;

dict = {
    'Asia':'red',
    'Europe':'green',
    'Africa':'blue',
    'Americas':'yellow',
    'Oceania':'black'
}

## alpha is the opacity of the colors

# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2,c=col,alpha=0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Show the plot
plt.show()

# %%
## ADDITIONAL CUSTOMIZATION

# adding the additional words "India" and "China" in the plot (these names can be seen on plot)

plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

plt.grid(True)  #and by this, we add grids on the plot
